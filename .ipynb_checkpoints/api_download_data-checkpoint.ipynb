# %% [markdown]
# # New York Living Local
# ----
#
# #### Note
# * We will be using Google Maps to locate points of interest with New York City
#     * DataFrame will be created
#     * Data Clean up to be performed
#     * Data will be stored in tables of Postgress DB

# %%
# Dependencies and Setup

import pandas as pd
import requests
import time
import os
from datetime import date
import json
from pprint import pprint

# Import API key
from api_keys import api_key

curdate = date.today().strftime("%m/%d/%Y")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API Calls
# Save config information and parameters
#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=new+york+city+point+of+interest&language=en&key=AIzaSyCZhPzDNVZW7U_8SbGMI2IrXpcK9gIio58"
city_var = "new+york"

params = {
    "query": f"{city_var}+point+of+interest",
    "key": api_key,
    "language": "en"
}

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

response = requests.get(url, params).json()

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Review API data
# type(response)
pprint(response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCBgEAAJ7A-FrShBW6Ln6vsKIm_kNlX53Nip2wHtNFeLOkeXMCUQaPgoJSGTEEFenxYew23FpZbJ_o90VwUBTDJ4H7TduRotw-RZ1CQxUar56TkDH1zkJKwK6vcDHxtvb41gxlbLuyL9R8c_WERXTqV0_pqQ14jrmV378oxiBAjvB_O03On4kGrFS4ryyU_Yn_AuhYlkHFgFSAZm6R6E-XBY-z04qEH3jxY9BbmMK6VHfOoY_zknjMw7ERCcwwS55KWaszOLI6JPAl5x8BUqZvaSrNaYccS3b2GBnbrGQgJfep8Mh4x_L3NU6LZOqXeGCt6sBJGBIRftOArIcu9uutf0qHFUcZHWwAt8Kx-q9WpH40qm1XEhDvCGepuUBE_MGFO4_JVbuBGhS5X1-VRxTx0-MayicRIsT1N4FtZg',
#  'results': [{'formatted_address': '10 South St, New York, NY 10004, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.6919879,
#                                         'lng': -74.01599499999999},
#                            'viewport': {'northeast': {'lat': 40.69333772989273,
#                                                       'lng': -74.01464517010727},
#                                         'southwest': {'lat': 40.69063807010728,
#                                                       'lng': -74.0173448298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png',
#               'id': 'e2568410beb651c76959c8c706e1d771fc316fa9',
#               'name': 'Governors Island National Monument',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4897,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106490258821111884682">Mark '
#                                                 'Furmanik</a>'],
#                           'photo_reference': 'CmRaAAAAyCEYdDf7TAyAPWn-4a5YKeMVtYmwgGxbIJ_A639-nxmwhK1fAaZ_h1I_FRygjDnaWU4JQ-BEB9bpCguGKeecGZOGaiCJ84ZP_lIwrsx4DqqkWd3xmvl-nWUBEnzJXsS-EhAHkgctDnUNia8WTZbIHLnDGhR7YWfqB7hsxo-BfdENeVdAiFkpHw',
#                           'width': 3266}],
#               'place_id': 'ChIJ2_ey6W9awokRxng4fzLDbPo',
#               'plus_code': {'compound_code': 'MXRM+QJ New York',
#                             'global_code': '87G7MXRM+QJ'},
#               'rating': 4.6,
#               'reference': 'ChIJ2_ey6W9awokRxng4fzLDbPo',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2675},
#              {'formatted_address': 'W 122nd St & Riverside Dr, New York, NY '
#                                    '10027, United States',
#               'geometry': {'location': {'lat': 40.8134045, 'lng': -73.9630671},
#                            'viewport': {'northeast': {'lat': 40.81479342989272,
#                                                       'lng': -73.96171487010727},
#                                         'southwest': {'lat': 40.81209377010728,
#                                                       'lng': -73.96441452989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png',
#               'id': '733dc3338625663c853d87af545babc054c43006',
#               'name': 'General Grant National Memorial',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109490048016942159532">Roel '
#                                                 'Schreurs</a>'],
#                           'photo_reference': 'CmRaAAAAujqcfyhakeoOhe-4twOf5CKznIHTgrV6i3zmpFeLdggGVZPGNe_9LWpFU6-WIQeUiqC5-zGt38uI6nerr8cNClnLKPZMm5AnwoD4C7jQMSbDcblCMd4fsWpryxwq9jOCEhCWKg8oBfuym_dC7RI3SnmZGhQo-mFNMK0O0mlrSy3ihfh8fgKBSQ',
#                           'width': 6016}],
#               'place_id': 'ChIJoxqn-kD2wokRLvhOLfAneU8',
#               'plus_code': {'compound_code': 'R27P+9Q New York',
#                             'global_code': '87G8R27P+9Q'},
#               'rating': 4.5,
#               'reference': 'ChIJoxqn-kD2wokRLvhOLfAneU8',
#               'types': ['tourist_attraction',
#                         'park',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 697},
#              {'formatted_address': '414 W 141st St, New York, NY 10031, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.8213537, 'lng': -73.9473103},
#                            'viewport': {'northeast': {'lat': 40.82289047989271,
#                                                       'lng': -73.94589007010728},
#                                         'southwest': {'lat': 40.82019082010727,
#                                                       'lng': -73.94858972989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '7fdf8be4d494f647a65700f36b00fa077e4f68d3',
#               'name': 'Hamilton Grange National Memorial',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113244420116672845924">Tim '
#                                                 'Sneath</a>'],
#                           'photo_reference': 'CmRaAAAAlpcKVmjhzRbS_KG-rhM1AYrvg43i1T-mGxJ6FkSnVpjNZSSNeadJredGI2P7k9P6pPUN1UxGmtG_bxgT6UMEyzs_AcW8Ev_OC_XDBG8mTtpJvr6G2og7A57uKS2o6ntlEhAsLO5KPPHM2IIcb9JKOzX8GhTznrOnAiHAUZvpZLDMDG2M69aduQ',
#                           'width': 4032}],
#               'place_id': 'ChIJ5wFJxXr2wokRQEmdWil_bEw',
#               'plus_code': {'compound_code': 'R3C3+G3 New York',
#                             'global_code': '87G8R3C3+G3'},
#               'rating': 4.5,
#               'reference': 'ChIJ5wFJxXr2wokRQEmdWil_bEw',
#               'types': ['tourist_attraction',
#                         'museum',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 529},
#              {'formatted_address': 'New York, NY 10004, United States',
#               'geometry': {'location': {'lat': 40.6892494,
#                                         'lng': -74.04450039999999},
#                            'viewport': {'northeast': {'lat': 40.71814749999999,
#                                                       'lng': -73.99872490000001},
#                                         'southwest': {'lat': 40.6796167,
#                                                       'lng': -74.05975889999998}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '5a0d7e67078e35af0c456a277df9ffba7c1e4da6',
#               'name': 'Statue of Liberty National Monument',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104615317245344911843">Brett '
#                                                 'Pyle</a>'],
#                           'photo_reference': 'CmRaAAAAhLUzPWicpbs8-IYKBauHV3Htonx2OdXwzExUyIlgmTJvKeNDVd2G0FL8VFdpD_fn3UtGvayn0dy7DumXncUFm1kSwONQ5sHN9QvgkQaF9M_bLTmV17G9jV53gSA6cjL6EhD2NPfifsnbV8ZFHVJ-zJvzGhSWyYxdWzEbAI3Iun41oaMWj9yiLg',
#                           'width': 3024}],
#               'place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#               'plus_code': {'compound_code': 'MXQ4+M5 New York',
#                             'global_code': '87G7MXQ4+M5'},
#               'rating': 4.7,
#               'reference': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#               'types': ['tourist_attraction',
#                         'park',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 66815},
#              {'formatted_address': '89 E 42nd St, New York, NY 10017, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.7525935, 'lng': -73.9767279},
#                            'viewport': {'northeast': {'lat': 40.75371032989272,
#                                                       'lng': -73.97479917010729},
#                                         'southwest': {'lat': 40.75101067010728,
#                                                       'lng': -73.97749882989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '096265fefe8d7d8c6f99699e4409d5aa84b17116',
#               'name': 'Grand Central Market',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3006,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115125443427453367948">Richard '
#                                                 'Fife</a>'],
#                           'photo_reference': 'CmRaAAAA-_DplnwEaHuJzOP2BcvrIi3vFBEAAikVFLeqC1GJJeRHYETeq7qJVqeJL2AVwAqQyNjzm3ve7U0kQNRY3uy8k3qtsGK27n8Td_0RHQj0jiA-009L2QN2XbAs92NWuGC9EhBnbXZsE-OlCIJlsJ4KIOukGhQVeOiJgICKc2pTs2NkiwpHzJVRmw',
#                           'width': 5344}],
#               'place_id': 'ChIJj9zIOgJZwokRuuxV79u6_nU',
#               'plus_code': {'compound_code': 'Q23F+28 New York',
#                             'global_code': '87G8Q23F+28'},
#               'rating': 4.5,
#               'reference': 'ChIJj9zIOgJZwokRuuxV79u6_nU',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1060},
#              {'formatted_address': 'Water St &, State St, New York, NY 10004, '
#                                    'United States',
#               'geometry': {'location': {'lat': 40.70218089999999,
#                                         'lng': -74.01499749999999},
#                            'viewport': {'northeast': {'lat': 40.70350567989272,
#                                                       'lng': -74.01319335},
#                                         'southwest': {'lat': 40.70080602010728,
#                                                       'lng': -74.01593035}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '2fad60c4a269d0c16dd2836b031c4c5161628550',
#               'name': 'SeaGlass Carousel',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103629638615749277925">Hugo '
#                                                 'Cruz</a>'],
#                           'photo_reference': 'CmRaAAAAsxZwuuo75tHIGE0sAJtFuXCtqvBJTwMLxXjCsLYu2n4OEn49NfhoVCXHbkE7Os0OFBuJQbZcaIMmKv045KZcEV7oR606RU4OcjMOT1WOHT30QtOhxLbu64DagPQNhHDWEhDJeZoh9XLLRAbJobWvL8dAGhTIrCqnH1RSyes7GvW7j6ONKFsYtg',
#                           'width': 6000}],
#               'place_id': 'ChIJryEQYRJawokR_bfRRa_lPqs',
#               'plus_code': {'compound_code': 'PX2P+V2 New York',
#                             'global_code': '87G7PX2P+V2'},
#               'rating': 4.5,
#               'reference': 'ChIJryEQYRJawokR_bfRRa_lPqs',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 496},
#              {'formatted_address': 'New York, NY, United States',
#               'geometry': {'location': {'lat': 40.7828647, 'lng': -73.9653551},
#                            'viewport': {'northeast': {'lat': 40.81804399999999,
#                                                       'lng': -73.9339825},
#                                         'southwest': {'lat': 40.7473416,
#                                                       'lng': -73.9970305}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png',
#               'id': 'c9bcef33f0cc85eda31f1c7444e9b1a3b82c9a9f',
#               'name': 'Central Park',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101472386159992727444">Garrett '
#                                                 'Hudson</a>'],
#                           'photo_reference': 'CmRaAAAA5ElSqAwmKQ8dKizT8I-RtZjs6cp4QPAsBTZY2eL6XW2EyNDeSuAsfLOmD1XEqnHuS6kcLxsKmx_--NIbiBFPo2GSoCDat2BTCtMx3gbm0nHUxG4EBh9hvTze8rbSpechEhC14nGwTAQ2IeQJxKnF8kQUGhQQvzruZ73Y4M_JigIOW_KhcxkfKg',
#                           'width': 3024}],
#               'place_id': 'ChIJ4zGFAZpYwokRGUGph3Mf37k',
#               'plus_code': {'compound_code': 'Q2MM+4V New York',
#                             'global_code': '87G8Q2MM+4V'},
#               'rating': 4.8,
#               'reference': 'ChIJ4zGFAZpYwokRGUGph3Mf37k',
#               'types': ['park',
#                         'tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 194445},
#              {'formatted_address': '20 W 34th St, New York, NY 10001, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.7484405,
#                                         'lng': -73.98566439999999},
#                            'viewport': {'northeast': {'lat': 40.74971142989272,
#                                                       'lng': -73.98392452010728},
#                                         'southwest': {'lat': 40.74701177010728,
#                                                       'lng': -73.98662417989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'bc232d2422e7068b2a2ffb314f02e3733dd47796',
#               'name': 'Empire State Building',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117951087160583633334">Empire '
#                                                 'State Building</a>'],
#                           'photo_reference': 'CmRaAAAA24mwFrFGts6ZtwboJY4h1NczeelJB2t8RDy38SblT9ayNsX-yCOlAH1l-7h3pFPJuRFlTj5YRFbWYzttaw7INSJ7p2W7LuywpU4075epDEpWRCa35X9Mnkh4_lXcmkH5EhCmfABGj0F6f997BOIFA4QEGhSBDUOqA-fVe_G7W6ggTCZqL88kTg',
#                           'width': 1280}],
#               'place_id': 'ChIJaXQRs6lZwokRY6EFpJnhNNE',
#               'plus_code': {'compound_code': 'P2X7+9P New York',
#                             'global_code': '87G8P2X7+9P'},
#               'rating': 4.7,
#               'reference': 'ChIJaXQRs6lZwokRY6EFpJnhNNE',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 70861},
#              {'formatted_address': 'Brooklyn Bridge, New York, NY 10038, '
#                                    'United States',
#               'geometry': {'location': {'lat': 40.7060855, 'lng': -73.9968643},
#                            'viewport': {'northeast': {'lat': 40.7192285,
#                                                       'lng': -73.9812363},
#                                         'southwest': {'lat': 40.6886497,
#                                                       'lng': -74.0112811}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'c1ac50eff9bb8e9505c59c69c4523ae94c4126fc',
#               'name': 'Brooklyn Bridge',
#               'photos': [{'height': 2618,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108804069346240761751">Marijn '
#                                                 'van der Woude</a>'],
#                           'photo_reference': 'CmRaAAAAXRSM6K-qOnF9Mw44XfGxz-5YM3FrwBdt3OBAU54eQfQ-8Yca9sAV3ZCmF2_n4dslGRcxmOkDJTMTA-6KdePHpCpiRgWZA1ymSCtfIgFfBfkFJap0isd7TsLB38jg8Z0hEhCDJPQMMJ8QnH3L-pQaMMpyGhRYBqqd5_FY16bqYyF4DsiRbpVvRQ',
#                           'width': 4656}],
#               'place_id': 'ChIJK3vOQyNawokRXEa9errdJiU',
#               'plus_code': {'compound_code': 'P243+C7 New York',
#                             'global_code': '87G8P243+C7'},
#               'rating': 4.8,
#               'reference': 'ChIJK3vOQyNawokRXEa9errdJiU',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 43920},
#              {'formatted_address': '5th Ave, New York, NY 10022, United States',
#               'geometry': {'location': {'lat': 40.7584653,
#                                         'lng': -73.97599269999999},
#                            'viewport': {'northeast': {'lat': 40.75987907989272,
#                                                       'lng': -73.97453474999999},
#                                         'southwest': {'lat': 40.75717942010727,
#                                                       'lng': -73.97777375}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/worship_general-71.png',
#               'id': 'acf24f96362bdabb64807f6c17cba8bb1d5b738a',
#               'name': "St. Patrick's Cathedral",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103645577548184875978">Sahar '
#                                                 'Sadjedi</a>'],
#                           'photo_reference': 'CmRaAAAAzHHva1E-l5aM6EfhpvwD4f3CvHmE9selj60wXQaizotTPjjSXnCAo_JGFa1X-sp9jEtiWUy-zLDBXdIBcpijhDrabptDEs3R_19J8dliBhpr2LH_oYnBjathKE3reAKUEhDLmV4hJXbM0n0-iKwFe1XwGhSmVEPJD_XVgT_Jujp2eC8zU6YIQw',
#                           'width': 3024}],
#               'place_id': 'ChIJUW4vEPxYwokRW6o24DU0YIg',
#               'plus_code': {'compound_code': 'Q25F+9J New York',
#                             'global_code': '87G8Q25F+9J'},
#               'rating': 4.8,
#               'reference': 'ChIJUW4vEPxYwokRW6o24DU0YIg',
#               'types': ['tourist_attraction',
#                         'church',
#                         'place_of_worship',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 24180},
#              {'formatted_address': 'New York, NY 10011, United States',
#               'geometry': {'location': {'lat': 40.7479925, 'lng': -74.0047649},
#                            'viewport': {'northeast': {'lat': 40.75890824999998,
#                                                       'lng': -73.99853175},
#                                         'southwest': {'lat': 40.73287364999999,
#                                                       'lng': -74.01141114999999}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png',
#               'id': '72dc79d023feec77725d7336e7c46fee27805319',
#               'name': 'The High Line',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3267,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105487997458497097901">Александр '
#                                                 'Иванов</a>'],
#                           'photo_reference': 'CmRaAAAAptfQbtBMYKWGCLDtyBaFWWS-c6LduVyBPAmUNbLYpNpy0RavO8w7s2t8uagQad9YXK4FqQQyW4VOmNjAkVyDyixFmtP_WoI6aWGXXPU318fwTUBm8aCygAo3U0dJMoHtEhAFd-9uQwDZ7PxQcVN07xmYGhTM9A8iZntQfppx4MlUebgDd63D3Q',
#                           'width': 4895}],
#               'place_id': 'ChIJ5bQPhMdZwokRkTwKhVxhP1g',
#               'plus_code': {'compound_code': 'PXXW+53 New York',
#                             'global_code': '87G7PXXW+53'},
#               'rating': 4.7,
#               'reference': 'ChIJ5bQPhMdZwokRkTwKhVxhP1g',
#               'types': ['park',
#                         'tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 38816},
#              {'formatted_address': '45 Rockefeller Plaza, New York, NY 10111, '
#                                    'United States',
#               'geometry': {'location': {'lat': 40.7587402, 'lng': -73.9786736},
#                            'viewport': {'northeast': {'lat': 40.75982057989272,
#                                                       'lng': -73.97721755},
#                                         'southwest': {'lat': 40.75712092010727,
#                                                       'lng': -73.98132935000001}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'af4e108e284a34cb052d51eb1eda880f18ff9d88',
#               'name': 'Rockefeller Center',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2248,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109009857293107840121">Jose '
#                                                 'Luis Zarate</a>'],
#                           'photo_reference': 'CmRaAAAApoSY6sFVOcgiwnflnP9Ni6qStjbxO22oqkEnGSta1DfciLhwaj0mUD3EZ0Vyz8Z-UGpI3euUddS7HIlhF-Kok77rLA_Xpx0VeyjSphYuONMi1HEzTMdgG-eJv6KD7xsHEhAXz8vufVS95m2acWYPTsK1GhRllMIj9OiQn9G8QACmL0V2tieiSw',
#                           'width': 4000}],
#               'place_id': 'ChIJ9U1mz_5YwokRosza1aAk0jM',
#               'plus_code': {'compound_code': 'Q25C+FG New York',
#                             'global_code': '87G8Q25C+FG'},
#               'rating': 4.6,
#               'reference': 'ChIJ9U1mz_5YwokRosza1aAk0jM',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 115447},
#              {'formatted_address': '30 Rockefeller Plaza, New York, NY 10112, '
#                                    'United States',
#               'geometry': {'location': {'lat': 40.7591205, 'lng': -73.9795267},
#                            'viewport': {'northeast': {'lat': 40.76060317989272,
#                                                       'lng': -73.97801842010728},
#                                         'southwest': {'lat': 40.75790352010728,
#                                                       'lng': -73.98071807989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'e05462d15e6f301386934e30734e0c6d39636b95',
#               'name': 'Top of the Rock',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1440,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111639147317210538021">Christopher '
#                                                 'Castro</a>'],
#                           'photo_reference': 'CmRaAAAAX2syB8Q9D9Ln7xZLBbPI_84map7OZdB9ctE8S9UGm0tksenIGWEPlGlQpAP0JNKzBeZthdu970h243AQBO2yV6q4G5wn5nOfRJFsbaMGFCNPKZljs82lSNUOhF5oYEI_EhDkWQ7BfubLXCXiUn2KwXywGhTvWUqPQ_vLmQN775TNCGGn6_tzUQ',
#                           'width': 2496}],
#               'place_id': 'ChIJe7vKMf9YwokRIMYfDz7iF9o',
#               'plus_code': {'compound_code': 'Q25C+J5 New York',
#                             'global_code': '87G8Q25C+J5'},
#               'rating': 4.7,
#               'reference': 'ChIJe7vKMf9YwokRIMYfDz7iF9o',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 34923},
#              {'formatted_address': '1000 5th Ave, New York, NY 10028, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.7794366, 'lng': -73.963244},
#                            'viewport': {'northeast': {'lat': 40.78025357989272,
#                                                       'lng': -73.96137637010729},
#                                         'southwest': {'lat': 40.77755392010728,
#                                                       'lng': -73.96407602989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png',
#               'id': 'f732f202150af1f14ae8a057a1014ceea6b33fc4',
#               'name': 'The Metropolitan Museum of Art',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115967679611787063919">Richard '
#                                                 'Stark</a>'],
#                           'photo_reference': 'CmRaAAAA66GladkkJMAQDhknYOLNBa5i1yDVyV8k5Ze3-cD30kZZ1xwELXOQSoSV4QocXEoz26Tbl99Ip8CYAplvc_UgOZj1F5ySyo_SDDR98P3DpYBM3OF6AFOkBhxTau_-ZxKgEhBhKOYmj85pI4fTb94KSmEjGhQXPArSLg5Lm7L7qGZlpIHVHj0zMA',
#                           'width': 4032}],
#               'place_id': 'ChIJb8Jg9pZYwokR-qHGtvSkLzs',
#               'plus_code': {'compound_code': 'Q2HP+QP New York',
#                             'global_code': '87G8Q2HP+QP'},
#               'price_level': 3,
#               'rating': 4.8,
#               'reference': 'ChIJb8Jg9pZYwokR-qHGtvSkLzs',
#               'types': ['art_gallery',
#                         'tourist_attraction',
#                         'museum',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 55252},
#              {'formatted_address': 'Pier 86, W 46th St, New York, NY 10036, '
#                                    'United States',
#               'geometry': {'location': {'lat': 40.7645266,
#                                         'lng': -73.99960759999999},
#                            'viewport': {'northeast': {'lat': 40.76578527989272,
#                                                       'lng': -73.99790007010728},
#                                         'southwest': {'lat': 40.76308562010728,
#                                                       'lng': -74.00059972989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png',
#               'id': '6bb43beb2047e4db91e332d24782460ccf8194c2',
#               'name': 'Intrepid Sea, Air & Space Museum',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110574460124929713793">Zaha '
#                                                 'A</a>'],
#                           'photo_reference': 'CmRaAAAAFCcSxL-07SzYnkbEybLh5h2h8WmATQwx35zTZx5KqG2UaSO3iddqipN5QmTMNZc1FXSEP8NYkiLW6IKmSJZGYARKAobIlKOO0T_zIAIiGHHsMKHY5qKEUiNAx81ekF-dEhDu8MEusbvAXY0NKBpwIotKGhSjmvfTbwyUfT9r-Mh8b50OiKHuKQ',
#                           'width': 4032}],
#               'place_id': 'ChIJnxlg1U5YwokR8T90UrZiIwI',
#               'plus_code': {'compound_code': 'Q272+R5 New York',
#                             'global_code': '87G8Q272+R5'},
#               'rating': 4.6,
#               'reference': 'ChIJnxlg1U5YwokR8T90UrZiIwI',
#               'types': ['museum',
#                         'tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 26007},
#              {'formatted_address': '1260 6th Ave, New York, NY 10020, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.75997599999999,
#                                         'lng': -73.9799772},
#                            'viewport': {'northeast': {'lat': 40.76128112989272,
#                                                       'lng': -73.97878962010728},
#                                         'southwest': {'lat': 40.75858147010728,
#                                                       'lng': -73.98148927989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '89dd7f0c82efc14f18954f8abf2925515037927a',
#               'name': 'Radio City Music Hall',
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105061948464149774244">walter '
#                                                 'thompson</a>'],
#                           'photo_reference': 'CmRaAAAACaoxx9OS7ORlsXgI8v-p0uk5bCBtKIB62HzXP5iNEjX8kFixnxOetDx8iBJP56GlZSdLqNd_SyAXrjLZuDnZJ62QQGrCBOeNRNeWq8nCTB3_T-BYQDRyTsAkFjJsR4FcEhD4iK_mfqbO5CcEPf6HFiJFGhQjA3_AUXfdtRLVee-7ouZgwUc8lw',
#                           'width': 3024}],
#               'place_id': 'ChIJPS8b1vhYwokRldqq2YHmxJI',
#               'plus_code': {'compound_code': 'Q25C+X2 New York',
#                             'global_code': '87G8Q25C+X2'},
#               'rating': 4.7,
#               'reference': 'ChIJPS8b1vhYwokRldqq2YHmxJI',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 16378},
#              {'formatted_address': '285 Fulton St, New York, NY 10006, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.7133444, 'lng': -74.0133677},
#                            'viewport': {'northeast': {'lat': 40.71436417989273,
#                                                       'lng': -74.01215482010727},
#                                         'southwest': {'lat': 40.71166452010728,
#                                                       'lng': -74.0148544798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '48cd459142d91a750ab1ac00141e799d2a7c1bfb',
#               'name': 'One World Observatory',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3888,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101181986155032856789">david '
#                                                 'jackson</a>'],
#                           'photo_reference': 'CmRaAAAARMBnuHQyPUQJoLQbU-SEzWUB4Ez2npooAePaN8pxj0AsxlcwxKuNbK2UM7_puoFOc76ALoqFB98qJxnCg2IaQWNtuiz5C3uWx-RlU34jRQ9cDbfIvEbx45QKZ2sVvFnHEhCq6WJHTh2ade7UdJ_dGeHHGhTJK3wZi-Oqt9lGO9LgJVg2SXvYyQ',
#                           'width': 5456}],
#               'place_id': 'ChIJTWE_0BtawokRVJNGH5RS448',
#               'plus_code': {'compound_code': 'PX7P+8M New York',
#                             'global_code': '87G7PX7P+8M'},
#               'price_level': 3,
#               'rating': 4.7,
#               'reference': 'ChIJTWE_0BtawokRVJNGH5RS448',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 13653},
#              {'formatted_address': '99 Margaret Corbin Dr, New York, NY 10040, '
#                                    'United States',
#               'geometry': {'location': {'lat': 40.8648628, 'lng': -73.9317274},
#                            'viewport': {'northeast': {'lat': 40.86665500000001,
#                                                       'lng': -73.9246285},
#                                         'southwest': {'lat': 40.86222299999999,
#                                                       'lng': -73.93519849999998}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png',
#               'id': '8edf774a665aeb294a6d6cf8df4405f4824f7e4f',
#               'name': 'The Met Cloisters',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 825,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108870268449526794997">Steve '
#                                                 'Lee</a>'],
#                           'photo_reference': 'CmRaAAAAaEo8gcfKCSN08uXLRwNPMMK_5McV8_IEJWxCG3MOG6nmokwtWwwLWRdRrmRD7ivOoDDrMPUjHkICG0xQYSVSyUdoIX9lchlfJj-3K6cUjmfUzjMGaTg4wFDrqGUNa76KEhAoAubVzPcXDCJyDlGd07z8GhSJnWLy9vBuu5Ft3iyIELM-QJfCww',
#                           'width': 1466}],
#               'place_id': 'ChIJK6bycAH0wokRrSnflfrnkZE',
#               'plus_code': {'compound_code': 'V379+W8 New York',
#                             'global_code': '87G8V379+W8'},
#               'rating': 4.7,
#               'reference': 'ChIJK6bycAH0wokRrSnflfrnkZE',
#               'types': ['tourist_attraction',
#                         'museum',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 4272},
#              {'formatted_address': 'New York, NY 10012, United States',
#               'geometry': {'location': {'lat': 40.7308228, 'lng': -73.997332},
#                            'viewport': {'northeast': {'lat': 40.7333674,
#                                                       'lng': -73.99379465},
#                                         'southwest': {'lat': 40.72847220000001,
#                                                       'lng': -74.00132525}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png',
#               'id': 'b0df149329a0f6a4006cc5328e3d42acadaf1b4f',
#               'name': 'Washington Square Park',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3744,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100843101132796394246">W '
#                                                 'L</a>'],
#                           'photo_reference': 'CmRaAAAAc896Nm0vNrE3WJsXT7TtsFO6N5KcRjbpmspC8zurt3n2BiB8TrYMFAwCSfYChAmkJQva4Scyyy2eBJqiXiperi4n0q7C_-ehDz-_jDkc-3Q148YC0UBG54Bmp8sO32F3EhDglGVJ6khOztIdcYp6F7shGhShfYB809aPFbh2SplxJZ6q6UT0wg',
#                           'width': 4274}],
#               'place_id': 'ChIJjX494pBZwokRGH620d9eYfo',
#               'plus_code': {'compound_code': 'P2J3+83 New York',
#                             'global_code': '87G8P2J3+83'},
#               'rating': 4.7,
#               'reference': 'ChIJjX494pBZwokRGH620d9eYfo',
#               'types': ['park',
#                         'tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 17650},
#              {'formatted_address': '11 W 53rd St, New York, NY 10019, United '
#                                    'States',
#               'geometry': {'location': {'lat': 40.7614327,
#                                         'lng': -73.97762159999999},
#                            'viewport': {'northeast': {'lat': 40.76300062989272,
#                                                       'lng': -73.97613242010728},
#                                         'southwest': {'lat': 40.76030097010727,
#                                                       'lng': -73.97883207989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png',
#               'id': '05fd8501e2532c0ea3033bd3f3a282ffff502863',
#               'name': 'The Museum of Modern Art',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1600,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108952592396835498631">Luis '
#                                                 'Marcoleta</a>'],
#                           'photo_reference': 'CmRaAAAAHYMVTaakOTxr5unaHyXjE1K-KiVqddsZqthv2FDGFtrADPP4Q3kjy4l0kpo3ghIZCSvyCYWqMCHt_8tbd1kTjUG5q93xLkocK_C6OZRCiy1ThGDLdkFdAbciauq67N8PEhAHgWRK62gXTDiJu0Ah9SM1GhSs3ZzG4Wiohvsdb0B0rgH-gc6dzw',
#                           'width': 1200}],
#               'place_id': 'ChIJKxDbe_lYwokRVf__s8CPn-o',
#               'plus_code': {'compound_code': 'Q26C+HX New York',
#                             'global_code': '87G8Q26C+HX'},
#               'rating': 4.6,
#               'reference': 'ChIJKxDbe_lYwokRVf__s8CPn-o',
#               'types': ['tourist_attraction',
#                         'museum',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 30268}],
#  'status': 'OK'}

# %%
#create list from response

response_list = [resp for resp in response["results"]]
print(len(response_list))
# Out:
# 20

# %%
#view on response

response_list[0]
# Out:
# {'formatted_address': '10 South St, New York, NY 10004, United States',
#  'geometry': {'location': {'lat': 40.6919879, 'lng': -74.01599499999999},
#   'viewport': {'northeast': {'lat': 40.69333772989273,
#     'lng': -74.01464517010727},
#    'southwest': {'lat': 40.69063807010728, 'lng': -74.0173448298927}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png',
#  'id': 'e2568410beb651c76959c8c706e1d771fc316fa9',
#  'name': 'Governors Island National Monument',
#  'opening_hours': {'open_now': False},
#  'photos': [{'height': 4897,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106490258821111884682">Mark Furmanik</a>'],
#    'photo_reference': 'CmRaAAAAyCEYdDf7TAyAPWn-4a5YKeMVtYmwgGxbIJ_A639-nxmwhK1fAaZ_h1I_FRygjDnaWU4JQ-BEB9bpCguGKeecGZOGaiCJ84ZP_lIwrsx4DqqkWd3xmvl-nWUBEnzJXsS-EhAHkgctDnUNia8WTZbIHLnDGhR7YWfqB7hsxo-BfdENeVdAiFkpHw',
#    'width': 3266}],
#  'place_id': 'ChIJ2_ey6W9awokRxng4fzLDbPo',
#  'plus_code': {'compound_code': 'MXRM+QJ New York',
#   'global_code': '87G7MXRM+QJ'},
#  'rating': 4.6,
#  'reference': 'ChIJ2_ey6W9awokRxng4fzLDbPo',
#  'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#  'user_ratings_total': 2675}

# %%
# set up lists to hold reponse infodata = []
city=[]
place = []
rating = []
rating_totals = []
address = []
latitude = []
longitude = []
count = 1

# Loop through the list of cities and perform a request for data on each
for response in response_list:
    try:
        city.append(city_var)
        place.append(response["name"])
        rating.append(response["rating"])
        rating_totals.append(response["user_ratings_total"])
        address.append(response["formatted_address"])
        latitude.append(response["geometry"]["location"]["lat"])
        longitude.append(response["geometry"]["location"]["lng"])
        count = count + 1
    except KeyError:
        print(f'City not found. Skipping... {city}')

print('------------------------------')
print(f'Data Retrieval Complete, Count {count}')
print('------------------------------')
# Out:
# ------------------------------
# Data Retrieval Complete, Count 21
# ------------------------------

# %%
city_data = pd.DataFrame({"city": city,
                            "place": place,
                            "rating": rating,
                            "rating_totals": rating_totals,
                            "address": address,
                            "latitude": latitude,
                            "Longitude": longitude})
#Save DF as csv

city_data.count()
# Out:
# city             20
# place            20
# rating           20
# rating_totals    20
# address          20
# latitude         20
# Longitude        20
# dtype: int64

# %%
city_data.head(25)
# Out:
#         city                                place  rating  rating_totals  \
# 0   new+york   Governors Island National Monument     4.6           2675
# 1   new+york      General Grant National Memorial     4.5            697
# 2   new+york    Hamilton Grange National Memorial     4.5            529
# 3   new+york  Statue of Liberty National Monument     4.7          66815
# 4   new+york                 Grand Central Market     4.5           1060
# 5   new+york                    SeaGlass Carousel     4.5            496
# 6   new+york                         Central Park     4.8         194445
# 7   new+york                Empire State Building     4.7          70861
# 8   new+york                      Brooklyn Bridge     4.8          43920
# 9   new+york              St. Patrick's Cathedral     4.8          24180
# 10  new+york                        The High Line     4.7          38816
# 11  new+york                   Rockefeller Center     4.6         115447
# 12  new+york                      Top of the Rock     4.7          34923
# 13  new+york       The Metropolitan Museum of Art     4.8          55252
# 14  new+york     Intrepid Sea, Air & Space Museum     4.6          26007
# 15  new+york                Radio City Music Hall     4.7          16378
# 16  new+york                One World Observatory     4.7          13653
# 17  new+york                    The Met Cloisters     4.7           4272
# 18  new+york               Washington Square Park     4.7          17650
# 19  new+york             The Museum of Modern Art     4.6          30268
#
#                                               address   latitude  Longitude
# 0      10 South St, New York, NY 10004, United States  40.691988 -74.015995
# 1   W 122nd St & Riverside Dr, New York, NY 10027,...  40.813404 -73.963067
# 2   414 W 141st St, New York, NY 10031, United States  40.821354 -73.947310
# 3                   New York, NY 10004, United States  40.689249 -74.044500
# 4     89 E 42nd St, New York, NY 10017, United States  40.752594 -73.976728
# 5   Water St &, State St, New York, NY 10004, Unit...  40.702181 -74.014997
# 6                         New York, NY, United States  40.782865 -73.965355
# 7     20 W 34th St, New York, NY 10001, United States  40.748441 -73.985664
# 8   Brooklyn Bridge, New York, NY 10038, United St...  40.706086 -73.996864
# 9          5th Ave, New York, NY 10022, United States  40.758465 -73.975993
# 10                  New York, NY 10011, United States  40.747993 -74.004765
# 11  45 Rockefeller Plaza, New York, NY 10111, Unit...  40.758740 -73.978674
# 12  30 Rockefeller Plaza, New York, NY 10112, Unit...  40.759121 -73.979527
# 13    1000 5th Ave, New York, NY 10028, United States  40.779437 -73.963244
# 14  Pier 86, W 46th St, New York, NY 10036, United...  40.764527 -73.999608
# 15    1260 6th Ave, New York, NY 10020, United States  40.759976 -73.979977
# 16   285 Fulton St, New York, NY 10006, United States  40.713344 -74.013368
# 17  99 Margaret Corbin Dr, New York, NY 10040, Uni...  40.864863 -73.931727
# 18                  New York, NY 10012, United States  40.730823 -73.997332
# 19    11 W 53rd St, New York, NY 10019, United States  40.761433 -73.977622
